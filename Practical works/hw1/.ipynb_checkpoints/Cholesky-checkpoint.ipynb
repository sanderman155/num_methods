# %%
import numpy as np
import numpy.linalg as ln
import matplotlib.pyplot as plt
import time

# %%
#n = int(input())
def Cholesky(A, L):
    L[0][0] = A[0][0] ** 0.5
    for i in range(n):
        L[i][0] = A[i][0]/L[0][0]
    for i in range(1, n):
        for j in range(1, i + 1):
            summ = 0
            if i == j:
                for k in range(j):
                    summ += L[i][k]*L[i][k]
                L[i][i] = (A[i][i] - summ) ** 0.5
            else:
                for k in range(j):
                    summ += L[i][k]*L[j][k]
                L[i][j] = (A[i][j] - summ) / L[j][j]
    return L

qTime = 0.0
n = 0
nList = []
qTimeList = []
while qTime <= 1.0:
    n += 20
    nList.append(n)
    A = np.random.uniform(0, n, (n, n)) * 10
    for i in range(n):
        for j in range(n):
            A[i][i] = A[i][i] + abs(A[i][j])
            A[i][j] = A[j][i]
    L = ln.cholesky(A)
    L1 = np.zeros((n, n))
    startTime = time.time()
    L1 = Cholesky(A, L1)
    qTime = time.time() - startTime
    qTimeList.append(qTime)
    print(f"n = {n}")
    print(f"time = {qTime}")
    fig, ax = plt.subplots()
    ax.plot(L1-L)
    plt.show()
    if n % 40 == 0:
        fig.savefig(f"Cholesky_graphics/{n:0.3d}x{n:0.3d}_{qTime:0.3f}sec.png")
fig, ax = plt.subplots()
ax.plot(nList, qTimeList)
plt.show()
fig.savefig("Cholecky_time_dependes_of_quantity.png")
# Out:
# n = 20
# time = 0.003864288330078125
# n = 40
# time = 0.02597641944885254
# n = 60
# time = 0.08182930946350098
# n = 80
# time = 0.11393570899963379
# n = 100
# time = 0.20075201988220215
# n = 120
# time = 0.3011360168457031
# n = 140
# time = 0.42449021339416504
# n = 160
# time = 0.667496919631958
# n = 180
# time = 0.9436659812927246
# n = 200
# time = 1.5360167026519775
